# %%
import pandas as pd

# %%
data = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv'

# %%
# !wget $data -O data_3.csv
# Out:
# --2023-09-30 10:13:42--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1475504 (1,4M) [text/plain]
# Saving to: ‘data_3.csv’
#
# data_3.csv          100%[===================>]   1,41M  1,26MB/s    in 1,1s
#
# 2023-09-30 10:13:43 (1,26 MB/s) - ‘data_3.csv’ saved [1475504/1475504]

# %%
df = pd.read_csv('data_3.csv')
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
data = df[['Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders', 'Transmission Type', 'Vehicle Style', 'highway MPG', 'city mpg']]

# %%
data
# Out:
#           Make       Model  Year  Engine HP  Engine Cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       Transmission Type  Vehicle Style  highway MPG  city mpg
# 0                MANUAL          Coupe           26        19
# 1                MANUAL    Convertible           28        19
# ...

# %%
data.columns = data.columns.str.replace(' ', '_').str.lower()

# %%
data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg
# 0                MANUAL          Coupe           26        19
# 1                MANUAL    Convertible           28        19
# ...

# %%
data.isnull().sum()
# Out:
# make                  0
# model                 0
# year                  0
# engine_hp            69
# engine_cylinders     30
# transmission_type     0
# vehicle_style         0
# highway_mpg           0
# city_mpg              0
# dtype: int64

# %%
data.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# dtype: object

# %%
data = data.fillna(0)

# %%
data.isnull().sum()
# Out:
# make                 0
# model                0
# year                 0
# engine_hp            0
# engine_cylinders     0
# transmission_type    0
# vehicle_style        0
# highway_mpg          0
# city_mpg             0
# dtype: int64

# %%
data.transmission_type.value_counts()
# Out:
# AUTOMATIC           8266
# MANUAL              2935
# AUTOMATED_MANUAL     626
# DIRECT_DRIVE          68
# UNKNOWN               19
# Name: transmission_type, dtype: int64

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df = df.rename(columns={'MSRP':'price'})

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
data.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# dtype: object

# %%
numerical = ['year', 'engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg']

# %%
data[numerical].corr()
# Out:
#                       year  engine_hp  engine_cylinders  highway_mpg  city_mpg
# year              1.000000   0.338714         -0.040708     0.258240  0.198171
# engine_hp         0.338714   1.000000          0.774851    -0.415707 -0.424918
# engine_cylinders -0.040708   0.774851          1.000000    -0.614541 -0.587306
# highway_mpg       0.258240  -0.415707         -0.614541     1.000000  0.886829
# city_mpg          0.198171  -0.424918         -0.587306     0.886829  1.000000

# %%
data[numerical].corr().abs()
# Out:
#                       year  engine_hp  engine_cylinders  highway_mpg  city_mpg
# year              1.000000   0.338714          0.040708     0.258240  0.198171
# engine_hp         0.338714   1.000000          0.774851     0.415707  0.424918
# engine_cylinders  0.040708   0.774851          1.000000     0.614541  0.587306
# highway_mpg       0.258240   0.415707          0.614541     1.000000  0.886829
# city_mpg          0.198171   0.424918          0.587306     0.886829  1.000000

# %%
data[numerical].corr().max()
# Out:
# year                1.0
# engine_hp           1.0
# engine_cylinders    1.0
# highway_mpg         1.0
# city_mpg            1.0
# dtype: float64

# %%
cm = data[numerical].corr()

# %%
np.fill_diagonal(cm.values, np.nan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 np.fill_diagonal(cm.values, np.nan)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
np.fill_diagonal(cm.values, np.nan)

# %%
cm
# Out:
#                       year  engine_hp  engine_cylinders  highway_mpg  city_mpg
# year                   NaN   0.338714         -0.040708     0.258240  0.198171
# engine_hp         0.338714        NaN          0.774851    -0.415707 -0.424918
# engine_cylinders -0.040708   0.774851               NaN    -0.614541 -0.587306
# highway_mpg       0.258240  -0.415707         -0.614541          NaN  0.886829
# city_mpg          0.198171  -0.424918         -0.587306     0.886829       NaN

# %%
cm.abs().max()
# Out:
# year                0.338714
# engine_hp           0.774851
# engine_cylinders    0.774851
# highway_mpg         0.886829
# city_mpg            0.886829
# dtype: float64

# %%
mean_price = df.price.mean()

# %%
df['price'].values
# Out:
# array([46135, 40650, 36350, ..., 50620, 50920, 28995])

# %%
above_average = df['price'].values > mean_price

# %%
above_average
# Out:
# array([ True,  True, False, ...,  True,  True, False])

# %%
above_average = above_average.astype(int)

# %%
above_average
# Out:
# array([1, 1, 0, ..., 1, 1, 0])

# %%
mean_price
# Out:
# 40594.737032063116

# %%
from sklearn.model_selection import train_test_split

# %%
data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg
# 0                MANUAL          Coupe           26        19
# 1                MANUAL    Convertible           28        19
# ...

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
data['above_average'] = above_average

# %%
data
# Out:
#           make       model  year  engine_hp  engine_cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       transmission_type  vehicle_style  highway_mpg  city_mpg  above_average
# 0                MANUAL          Coupe           26        19              1
# ...

# %%
df_fulltrain, df_test = train_test_split(data, test_size=0.2, random_state=42)

# %%
len(df_fulltrain), len(df_test)
# Out:
# (9531, 2383)

# %%
df_train, df_val = train_test_split(df_fulltrain, test_size=0.25, random_state=42)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (7148, 2383, 2383)

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.above_average.values
y_val = df_val.above_average.values
y_test = df_test.above_average.values

# %%
del df_train['above_average']
del df_val['above_average']
del df_test['above_average']

# %%
from sklearn.metrics import mutual_info_score

# %%
data.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# above_average          int64
# dtype: object

# %%
categorical = ['make', 'model', 'transmission_type', 'vehicle_style']

# %%
categorical
# Out:
# ['make', 'model', 'transmission_type', 'vehicle_style']

# %%
def mutual_info_above_average_score(series):
    return mutual_info_score(series, y_train)

# %%
mis = df_train[categorical].apply(mutual_info_above_average_score)
mis
# Out:
# make                 0.239769
# model                0.462344
# transmission_type    0.020958
# vehicle_style        0.084143
# dtype: float64

# %%
mis_sorted = mis.sort_values(ascending=False)
mis_sorted
# Out:
# model                0.462344
# make                 0.239769
# vehicle_style        0.084143
# transmission_type    0.020958
# dtype: float64

# %%
round(mis_sorted, 2)
# Out:
# model                0.46
# make                 0.24
# vehicle_style        0.08
# transmission_type    0.02
# dtype: float64

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
dicts_train = df_train.to_dict(orient='records')

# %%
dicts_train
# Out:
# [{'make': 'Mitsubishi',
#   'model': 'Endeavor',
#   'year': 2011,
#   'engine_hp': 225.0,
#   'engine_cylinders': 6.0,
#   'transmission_type': 'AUTOMATIC',
#   'vehicle_style': '4dr SUV',
#   'highway_mpg': 19,
#   'city_mpg': 15},
#  {'make': 'Kia',
#   'model': 'Borrego',
#   'year': 2009,
#   'engine_hp': 276.0,
#   'engine_cylinders': 6.0,
#   'transmission_type': 'AUTOMATIC',
#   'vehicle_style': '4dr SUV',
#   'highway_mpg': 21,
#   'city_mpg': 17},
#  {'make': 'Lamborghini',
#   'model': 'Gallardo',
#   'year': 2012,
#   'engine_hp': 570.0,
#   'engine_cylinders': 10.0,
#   'transmission_type': 'MANUAL',
#   'vehicle_style': 'Convertible',
#   'highway_mpg': 20,
#   'city_mpg': 12},
#  {'make': 'Chevrolet',
#   'model': 'Colorado',
#   'year': 2016,
#   'engine_hp': 200.0,
#   'engine_cylinders': 4.0,
#   'transmission_type': 'AUTOMATIC',
#   'vehicle_style': 'Crew Cab Pickup',
#   'highway_mpg': 27,
#   'city_mpg': 20},
#  {'make': 'Pontiac',
#   'model': 'Vibe',
# ...

# %%
dv = DictVectorizer(sparse=False)

# %%
X_train = dv.fit_transform(dicts_train)

# %%
X_train
# Out:
# array([[1.500e+01, 6.000e+00, 2.250e+02, ..., 0.000e+00, 0.000e+00,
#         2.011e+03],
#        [1.700e+01, 6.000e+00, 2.760e+02, ..., 0.000e+00, 0.000e+00,
#         2.009e+03],
#        [1.200e+01, 1.000e+01, 5.700e+02, ..., 0.000e+00, 0.000e+00,
#         2.012e+03],
#        ...,
#        [1.700e+01, 6.000e+00, 2.600e+02, ..., 0.000e+00, 0.000e+00,
#         2.012e+03],
#        [1.900e+01, 4.000e+00, 1.360e+02, ..., 0.000e+00, 0.000e+00,
#         1.993e+03],
#        [1.700e+01, 6.000e+00, 3.650e+02, ..., 1.000e+00, 0.000e+00,
#         2.015e+03]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=10, max_iter=1000, random_state=42, solver='liblinear')

# %%
dicts_val = df_val.to_dict(orient='records')

# %%
X_val = dv.transform(dicts_val)

# %%
y_pred = model.predict_proba(X_val)[:,1]

# %%
y_pred
# Out:
# array([0.0087346 , 0.99033279, 0.00157489, ..., 0.00145975, 0.97178288,
#        0.96248167])

# %%
above_average_decision = (y_pred >= 0.5)

# %%
above_average_decision
# Out:
# array([False,  True, False, ..., False,  True,  True])

# %%
q4_answer = (above_average_decision == y_val).mean()
q4_answer
# Out:
# 0.9345362987830466

# %%
round(q4_answer, 2)
# Out:
# 0.93

# %%
categorical
# Out:
# ['make', 'model', 'transmission_type', 'vehicle_style']

# %%
numerical
# Out:
# ['year', 'engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg']

# %%
def least_useful_feature():
    all_features = categorical + numerical
    
    for f in all_features:
        
        subset_features = all_features.copy()
        subset_features.remove(f)
        
        dicts_train = df_train[subset_features].to_dict(orient='records')
        dv = DictVectorizer(sparse=False)
        X_train = dv.fit_transform(dicts_train)
        model = LogisticRegression(solver='liblinear', C=10, max_iter=1000, random_state=42)
        model.fit(X_train, y_train)
        dicts_val = df_val[subset_features].to_dict(orient='records')
        X_val = dv.transform(dicts_val)
        y_pred = model.predict_proba(X_val)[:,1]
        above_average_decision = (y_pred >= 0.5)
        score_without_f = (above_average_decision == y_val).mean()
        
        print(f, score_without_f, q4_answer - score_without_f)

# %%
least_useful_feature()
# Out:
# make 0.9450272765421738 -0.010490977759127218
# model 0.9240453210239195 0.010490977759127107
# transmission_type 0.9458665547629039 -0.011330255979857373
# vehicle_style 0.9328577423415862 0.0016785564414603105
# year 0.9475451112043642 -0.013008812421317684
# engine_hp 0.9299202685690307 0.004616030214015909
# engine_cylinders 0.9458665547629039 -0.011330255979857373
# highway_mpg 0.9467058329836341 -0.012169534200587528
# city_mpg 0.9458665547629039 -0.011330255979857373
